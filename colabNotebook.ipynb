# %% [markdown]
# <a href="https://colab.research.google.com/github/uoscar-s-urrego/Handwritten-Digit-Recognition-CNN/blob/main/colabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Libraries import

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from google.colab import files

# %% [markdown]
# #Splitting the MNIST dataset into Train and Test

# %%
(x_train,y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# #Preprocessing the input data

# %%
num_of_trainImgs = x_train.shape[0] # 6000 here
num_of_testImgs = x_test.shape[0] # 1000 here
img_width = 28
img_heigt = 28

x_train = x_train.reshape(x_train.shape[0], img_width, img_heigt, 1)
x_test = x_test.reshape(x_test.shape[0], img_width, img_heigt, 1)
input_shape = (img_width, img_heigt, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# #Converting the class vectors to binary class

# %%
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# #Defining the model architecture

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compiling the model

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer = keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %% [markdown]
# #Fitting the model on training data

# %%
model.fit(x_train, y_train,
          batch_size = 128,
          epochs = 12,
          verbose = 1,
          validation_data = (x_test, y_test))
# Out:
# Epoch 1/12
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 168s 352ms/step - accuracy: 0.1068 - loss: 2.2915 - val_accuracy: 0.2504 - val_loss: 2.2474
# Epoch 2/12
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 156s 332ms/step - accuracy: 0.2015 - loss: 2.2421 - val_accuracy: 0.3749 - val_loss: 2.1829
# Epoch 3/12
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 159s 340ms/step - accuracy: 0.2852 - loss: 2.1806 - val_accuracy: 0.4753 - val_loss: 2.0961
# Epoch 4/12
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 199s 333ms/step - accuracy: 0.3788 - loss: 2.0939 - val_accuracy: 0.5971 - val_loss: 1.9780
# Epoch 5/12
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 158s 337ms/step - accuracy: 0.4615 - loss: 1.9784 - val_accuracy: 0.7073 - val_loss: 1.8196
# Epoch 6/12
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 205s 344ms/step - accuracy: 0.5332 - loss: 1.8326 - val_accuracy: 0.7582 - val_loss: 1.6224
# Epoch 7/12
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 198s 336ms/step - accuracy: 0.5912 - loss: 1.6556 - val_accuracy: 0.7860 - val_loss: 1.4064
# Epoch 8/12
# ...

# %%
model.save('trained_model.keras')
files.download('trained_model.keras')
